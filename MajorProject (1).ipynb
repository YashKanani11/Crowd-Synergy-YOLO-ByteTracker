# %%
# !nvidia-smi
# Out:
# Thu May 30 05:59:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
pip install numpy==1.22.4
# Out:
# Requirement already satisfied: numpy==1.22.4 in /usr/local/lib/python3.10/dist-packages (1.22.4)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download video

# %%
SOURCE_VIDEO_PATH = "/content/Shopping, People, Commerce, Mall, Many, Crowd, Walking   Free Stock video footage   YouTube.mp4"

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.25 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/78.2 GB disk)

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# settings
MODEL = "yolov8x.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|██████████| 131M/131M [00:00<00:00, 357MB/s]
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs

# %% [markdown]
# ## Predict and annotate single frame

# %%
model.model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - people for now{can be changed dynamically}
CLASS_ID = [0]

# %%
SOURCE_VIDEO_PATH = '/content/Shopping, People, Commerce, Mall, Many, Crowd, Walking   Free Stock video footage   YouTube.mp4'  # Replace with your video path
FRAME_INDEX = 300  # Change this to the index of the desired frame

# Create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)

# Create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=1, text_thickness=1, text_scale=1)

# Skip to the desired frame
frame = None
for i in range(FRAME_INDEX + 1):
    try:
        frame = next(generator)
    except StopIteration:
        print(f"Video has less than {FRAME_INDEX + 1} frames.")
        break

# Ensure the frame is obtained
if frame is not None:
    # Model prediction on single frame and conversion to supervision Detections
    results = model(frame)
    detections = Detections(
        xyxy=results[0].boxes.xyxy.cpu().numpy(),
        confidence=results[0].boxes.conf.cpu().numpy(),
        class_id=results[0].boxes.cls.cpu().numpy().astype(int)
    )

    # Format custom labels
    labels = [
        f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
        for _, confidence, class_id, tracker_id
        in detections
    ]

    # Annotate and display frame
    frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

    # Display the frame
    # %matplotlib inline
    show_frame_in_notebook(frame, (16, 16))
else:
    print("Failed to retrieve the specified frame.")
# Out:
# 0: 384x640 27 persons, 4 backpacks, 2 handbags, 1 frisbee, 62.1ms
# Speed: 3.2ms preprocess, 62.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = Point(20, 350)
LINE_END = Point(1280-20, 350)

TARGET_VIDEO_PATH = f"{HOME}/Crowd_Counting.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1280, height=720, fps=25, total_frames=341)

# %%
from tqdm.notebook import tqdm


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=1, text_thickness=1, text_scale=1)
line_annotator = LineCounterAnnotator(thickness=1, text_thickness=2, text_scale=1)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
#   0%|          | 0/341 [00:00<?, ?it/s]
# 0: 384x640 29 persons, 4 handbags, 3 frisbees, 62.1ms
# Speed: 2.1ms preprocess, 62.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 3 frisbees, 62.0ms
# Speed: 2.2ms preprocess, 62.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 1 handbag, 3 frisbees, 55.0ms
# Speed: 6.2ms preprocess, 55.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 handbags, 3 frisbees, 53.9ms
# Speed: 1.9ms preprocess, 53.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 handbags, 3 frisbees, 47.8ms
# Speed: 2.0ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 handbags, 2 frisbees, 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 3 frisbees, 34.5ms
# Speed: 3.3ms preprocess, 34.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 frisbees, 32.3ms
# Speed: 3.0ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 3 frisbees, 30.5ms
# Speed: 2.9ms preprocess, 30.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 1 handbag, 3 frisbees, 30.6ms
# Speed: 2.3ms preprocess, 30.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 1 handbag, 3 frisbees, 30.5ms
# Speed: 3.4ms preprocess, 30.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 1 handbag, 3 frisbees, 30.6ms
# Speed: 2.3ms preprocess, 30.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 2 handbags, 3 frisbees, 29.9ms
# Speed: 2.5ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 2 handbags, 3 frisbees, 30.6ms
# Speed: 2.1ms preprocess, 30.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 3 handbags, 2 frisbees, 30.0ms
# Speed: 2.4ms preprocess, 30.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 3 handbags, 2 frisbees, 30.1ms
# Speed: 1.8ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 2 frisbees, 30.4ms
# Speed: 1.9ms preprocess, 30.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 1 handbag, 2 frisbees, 29.7ms
# Speed: 1.7ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 2 frisbees, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 frisbees, 29.1ms
# Speed: 2.2ms preprocess, 29.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 2 frisbees, 30.8ms
# Speed: 2.1ms preprocess, 30.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 28.8ms
# Speed: 2.1ms preprocess, 28.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 2 handbags, 29.7ms
# Speed: 2.2ms preprocess, 29.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 backpacks, 1 handbag, 29.4ms
# Speed: 2.1ms preprocess, 29.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 3 backpacks, 2 handbags, 1 frisbee, 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 1 frisbee, 29.5ms
# Speed: 2.3ms preprocess, 29.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 1 frisbee, 29.6ms
# Speed: 2.2ms preprocess, 29.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 1 frisbee, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 1 frisbee, 30.0ms
# Speed: 4.8ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 1 frisbee, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 30.1ms
# Speed: 2.1ms preprocess, 30.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 1 frisbee, 29.7ms
# Speed: 2.5ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 1 frisbee, 30.6ms
# Speed: 2.1ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 frisbee, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 frisbee, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 29.5ms
# Speed: 3.8ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 29.7ms
# Speed: 5.5ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 29.7ms
# Speed: 2.3ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 1 handbag, 30.0ms
# Speed: 1.8ms preprocess, 30.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 2 handbags, 30.2ms
# Speed: 2.2ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 handbags, 30.4ms
# Speed: 2.0ms preprocess, 30.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 handbag, 30.5ms
# Speed: 2.0ms preprocess, 30.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 backpacks, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 4 backpacks, 1 frisbee, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 backpacks, 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 backpacks, 2 frisbees, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 4 backpacks, 2 frisbees, 28.9ms
# Speed: 4.9ms preprocess, 28.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 backpacks, 2 frisbees, 29.6ms
# Speed: 2.7ms preprocess, 29.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 backpacks, 1 handbag, 2 frisbees, 29.4ms
# Speed: 1.9ms preprocess, 29.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 backpacks, 1 handbag, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 backpacks, 1 frisbee, 29.5ms
# Speed: 1.9ms preprocess, 29.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 handbag, 28.8ms
# Speed: 2.0ms preprocess, 28.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 4 backpacks, 1 handbag, 1 frisbee, 29.8ms
# Speed: 2.1ms preprocess, 29.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 backpacks, 1 handbag, 29.2ms
# Speed: 2.7ms preprocess, 29.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 2 handbags, 3 frisbees, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 handbag, 3 frisbees, 29.4ms
# Speed: 2.0ms preprocess, 29.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 1 handbag, 2 frisbees, 30.0ms
# Speed: 3.1ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 backpacks, 1 handbag, 1 frisbee, 30.0ms
# Speed: 2.3ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 handbag, 29.8ms
# Speed: 1.7ms preprocess, 29.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 2 handbags, 1 snowboard, 29.8ms
# Speed: 2.7ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 2 handbags, 1 frisbee, 30.9ms
# Speed: 2.1ms preprocess, 30.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 3 handbags, 1 frisbee, 29.2ms
# Speed: 1.9ms preprocess, 29.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 backpacks, 2 handbags, 1 frisbee, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 backpacks, 2 handbags, 1 frisbee, 36.3ms
# Speed: 2.4ms preprocess, 36.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 3 backpacks, 2 handbags, 1 frisbee, 30.1ms
# Speed: 2.3ms preprocess, 30.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 backpacks, 2 handbags, 1 frisbee, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 2 handbags, 2 frisbees, 29.4ms
# Speed: 2.2ms preprocess, 29.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 backpacks, 2 handbags, 2 frisbees, 29.4ms
# Speed: 2.1ms preprocess, 29.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 2 frisbees, 29.8ms
# Speed: 1.8ms preprocess, 29.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 2 frisbees, 29.7ms
# Speed: 1.9ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 2 frisbees, 29.8ms
# Speed: 2.4ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 2 frisbees, 29.7ms
# Speed: 1.9ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 2 frisbees, 29.6ms
# Speed: 2.6ms preprocess, 29.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 2 frisbees, 29.1ms
# Speed: 2.0ms preprocess, 29.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 handbags, 2 frisbees, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 handbags, 2 frisbees, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 2 frisbees, 29.6ms
# Speed: 3.3ms preprocess, 29.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 backpack, 2 frisbees, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 2 frisbees, 28.9ms
# Speed: 2.0ms preprocess, 28.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 backpack, 2 frisbees, 1 tennis racket, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 backpack, 1 handbag, 2 frisbees, 1 tennis racket, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 backpack, 2 frisbees, 1 tennis racket, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 backpack, 2 frisbees, 1 tennis racket, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 frisbees, 1 tennis racket, 29.2ms
# Speed: 2.1ms preprocess, 29.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 2 frisbees, 1 tennis racket, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 2 frisbees, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 1 handbag, 2 frisbees, 29.7ms
# Speed: 2.4ms preprocess, 29.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 29.9ms
# Speed: 2.3ms preprocess, 29.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 2 frisbees, 30.3ms
# Speed: 2.3ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 2 frisbees, 29.2ms
# Speed: 2.6ms preprocess, 29.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 backpacks, 1 handbag, 2 frisbees, 29.5ms
# Speed: 1.8ms preprocess, 29.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 1 handbag, 2 frisbees, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 backpack, 1 handbag, 2 frisbees, 29.2ms
# Speed: 2.8ms preprocess, 29.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 2 frisbees, 29.7ms
# Speed: 4.2ms preprocess, 29.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 2 frisbees, 29.6ms
# Speed: 2.3ms preprocess, 29.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 2 frisbees, 30.2ms
# Speed: 2.4ms preprocess, 30.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 2 frisbees, 29.5ms
# Speed: 2.7ms preprocess, 29.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 handbags, 2 frisbees, 31.8ms
# Speed: 2.2ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 2 frisbees, 29.9ms
# Speed: 2.4ms preprocess, 29.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 2 frisbees, 29.5ms
# Speed: 3.1ms preprocess, 29.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 2 frisbees, 28.8ms
# Speed: 3.1ms preprocess, 28.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 1 frisbee, 28.9ms
# Speed: 2.1ms preprocess, 28.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 1 frisbee, 29.0ms
# Speed: 4.8ms preprocess, 29.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 1 frisbee, 29.0ms
# Speed: 2.1ms preprocess, 29.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 1 frisbee, 29.2ms
# Speed: 2.3ms preprocess, 29.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 1 frisbee, 29.0ms
# Speed: 2.1ms preprocess, 29.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 1 frisbee, 28.8ms
# Speed: 2.2ms preprocess, 28.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 28.8ms
# Speed: 2.3ms preprocess, 28.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 1 frisbee, 29.4ms
# Speed: 2.1ms preprocess, 29.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 28.8ms
# Speed: 1.7ms preprocess, 28.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 1 frisbee, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 30.7ms
# Speed: 2.0ms preprocess, 30.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 2 frisbees, 29.7ms
# Speed: 3.0ms preprocess, 29.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 frisbees, 31.4ms
# Speed: 2.1ms preprocess, 31.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 2 frisbees, 29.7ms
# Speed: 4.9ms preprocess, 29.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 2 handbags, 1 frisbee, 29.0ms
# Speed: 3.5ms preprocess, 29.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 backpacks, 1 handbag, 1 frisbee, 29.2ms
# Speed: 2.1ms preprocess, 29.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 2 frisbees, 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 2 frisbees, 29.8ms
# Speed: 2.6ms preprocess, 29.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 2 frisbees, 29.2ms
# Speed: 2.3ms preprocess, 29.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 2 frisbees, 29.1ms
# Speed: 2.3ms preprocess, 29.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 3 frisbees, 30.0ms
# Speed: 2.1ms preprocess, 30.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 3 handbags, 3 frisbees, 29.0ms
# Speed: 2.2ms preprocess, 29.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 3 frisbees, 31.6ms
# Speed: 8.6ms preprocess, 31.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 2 frisbees, 35.9ms
# Speed: 3.3ms preprocess, 35.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 handbags, 2 frisbees, 39.6ms
# Speed: 2.2ms preprocess, 39.6ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 3 frisbees, 28.7ms
# Speed: 2.1ms preprocess, 28.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 2 frisbees, 28.8ms
# Speed: 2.2ms preprocess, 28.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 1 frisbee, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 handbags, 3 frisbees, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 2 frisbees, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 3 frisbees, 30.0ms
# Speed: 4.1ms preprocess, 30.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 frisbees, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 handbag, 2 frisbees, 28.9ms
# Speed: 2.3ms preprocess, 28.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 handbags, 2 frisbees, 30.5ms
# Speed: 2.1ms preprocess, 30.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 2 frisbees, 28.7ms
# Speed: 2.2ms preprocess, 28.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 handbags, 2 frisbees, 29.4ms
# Speed: 2.8ms preprocess, 29.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 handbag, 2 frisbees, 29.9ms
# Speed: 2.1ms preprocess, 29.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 1 frisbee, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 3 handbags, 1 frisbee, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 29.4ms
# Speed: 2.0ms preprocess, 29.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 29.7ms
# Speed: 1.7ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 1 frisbee, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 29.4ms
# Speed: 1.9ms preprocess, 29.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 29.5ms
# Speed: 2.7ms preprocess, 29.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 29.7ms
# Speed: 2.2ms preprocess, 29.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 29.4ms
# Speed: 2.0ms preprocess, 29.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 1 frisbee, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 1 frisbee, 29.9ms
# Speed: 2.2ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 29.9ms
# Speed: 2.1ms preprocess, 29.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 1 frisbee, 29.8ms
# Speed: 2.1ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 1 frisbee, 30.3ms
# Speed: 2.1ms preprocess, 30.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 1 frisbee, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 1 frisbee, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 handbags, 30.8ms
# Speed: 1.9ms preprocess, 30.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 handbags, 30.1ms
# Speed: 2.9ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 30.5ms
# Speed: 1.9ms preprocess, 30.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 29.9ms
# Speed: 3.9ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 29.6ms
# Speed: 1.9ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 1 frisbee, 30.2ms
# Speed: 4.1ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 3 handbags, 1 frisbee, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 3 handbags, 1 frisbee, 29.5ms
# Speed: 1.7ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 2 handbags, 1 frisbee, 29.4ms
# Speed: 1.9ms preprocess, 29.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 3 handbags, 1 frisbee, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 4 handbags, 1 frisbee, 30.0ms
# Speed: 2.1ms preprocess, 30.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 handbags, 1 frisbee, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 4 handbags, 1 frisbee, 29.9ms
# Speed: 1.9ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 1 frisbee, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 1 frisbee, 30.2ms
# Speed: 3.7ms preprocess, 30.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 4 handbags, 1 frisbee, 30.1ms
# Speed: 2.2ms preprocess, 30.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 29.7ms
# Speed: 2.8ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 1 frisbee, 29.9ms
# Speed: 2.2ms preprocess, 29.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 29.9ms
# Speed: 1.9ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 29.8ms
# Speed: 2.0ms preprocess, 29.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 2 frisbees, 30.0ms
# Speed: 2.1ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 2 frisbees, 29.5ms
# Speed: 1.9ms preprocess, 29.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 2 frisbees, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 3 frisbees, 29.9ms
# Speed: 2.2ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 3 frisbees, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 3 frisbees, 30.2ms
# Speed: 2.1ms preprocess, 30.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 30.2ms
# Speed: 1.8ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 30.5ms
# Speed: 2.2ms preprocess, 30.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 29.5ms
# Speed: 2.1ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 1 handbag, 2 frisbees, 30.5ms
# Speed: 2.2ms preprocess, 30.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 2 frisbees, 29.8ms
# Speed: 1.9ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 3 frisbees, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 3 handbags, 3 frisbees, 29.5ms
# Speed: 1.8ms preprocess, 29.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 2 frisbees, 29.6ms
# Speed: 1.9ms preprocess, 29.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 2 frisbees, 29.8ms
# Speed: 1.9ms preprocess, 29.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 2 frisbees, 29.7ms
# Speed: 1.9ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 3 frisbees, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 1 frisbee, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 backpacks, 3 handbags, 2 frisbees, 29.5ms
# Speed: 1.9ms preprocess, 29.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 2 handbags, 1 frisbee, 30.2ms
# Speed: 2.2ms preprocess, 30.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 3 handbags, 1 frisbee, 29.3ms
# Speed: 1.6ms preprocess, 29.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 1 frisbee, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 1 frisbee, 29.5ms
# Speed: 2.0ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 1 frisbee, 29.7ms
# Speed: 1.9ms preprocess, 29.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 1 frisbee, 29.9ms
# Speed: 2.3ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 handbags, 1 frisbee, 30.2ms
# Speed: 2.0ms preprocess, 30.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 handbag, 1 frisbee, 32.1ms
# Speed: 2.6ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 handbags, 1 frisbee, 1 tennis racket, 30.5ms
# Speed: 2.0ms preprocess, 30.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 30.7ms
# Speed: 1.9ms preprocess, 30.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 1 frisbee, 1 tennis racket, 30.4ms
# Speed: 3.6ms preprocess, 30.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 handbags, 2 frisbees, 1 tennis racket, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 4 handbags, 2 frisbees, 1 tennis racket, 29.6ms
# Speed: 2.2ms preprocess, 29.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 handbags, 1 frisbee, 1 tennis racket, 29.8ms
# Speed: 2.2ms preprocess, 29.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 1 frisbee, 30.2ms
# Speed: 2.0ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 2 handbags, 1 frisbee, 30.3ms
# Speed: 2.0ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 handbags, 3 frisbees, 30.2ms
# Speed: 2.3ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 handbags, 3 frisbees, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 3 handbags, 2 frisbees, 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 2 handbags, 1 frisbee, 30.2ms
# Speed: 2.0ms preprocess, 30.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 handbags, 1 frisbee, 30.4ms
# Speed: 1.9ms preprocess, 30.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 2 frisbees, 30.3ms
# Speed: 2.1ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 handbags, 2 frisbees, 30.4ms
# Speed: 1.9ms preprocess, 30.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 2 handbags, 2 frisbees, 30.1ms
# Speed: 3.2ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 4 handbags, 2 frisbees, 30.3ms
# Speed: 2.4ms preprocess, 30.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 handbags, 2 frisbees, 29.5ms
# Speed: 1.9ms preprocess, 29.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 1 frisbee, 1 skateboard, 29.8ms
# Speed: 1.8ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 handbags, 1 frisbee, 1 skateboard, 29.4ms
# Speed: 2.3ms preprocess, 29.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 1 frisbee, 1 skateboard, 29.9ms
# Speed: 1.9ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 handbags, 1 frisbee, 29.6ms
# Speed: 1.9ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 29.9ms
# Speed: 1.6ms preprocess, 29.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 handbags, 1 frisbee, 29.5ms
# Speed: 2.5ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 1 handbag, 1 frisbee, 29.8ms
# Speed: 1.9ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 frisbee, 30.0ms
# Speed: 1.8ms preprocess, 30.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 1 handbag, 1 frisbee, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 2 handbags, 2 frisbees, 30.5ms
# Speed: 2.1ms preprocess, 30.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 4 handbags, 2 frisbees, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 3 handbags, 2 frisbees, 29.9ms
# Speed: 1.7ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 2 handbags, 2 frisbees, 30.0ms
# Speed: 2.6ms preprocess, 30.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 4 handbags, 2 frisbees, 35.7ms
# Speed: 2.1ms preprocess, 35.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 handbags, 2 frisbees, 29.5ms
# Speed: 2.7ms preprocess, 29.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 handbags, 1 frisbee, 1 tennis racket, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 2 handbags, 1 frisbee, 29.5ms
# Speed: 2.0ms preprocess, 29.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 handbags, 1 frisbee, 1 tennis racket, 29.7ms
# Speed: 3.6ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 handbags, 1 frisbee, 1 tennis racket, 29.4ms
# Speed: 1.7ms preprocess, 29.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 30.2ms
# Speed: 2.1ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 1 handbag, 2 frisbees, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 2 frisbees, 1 tennis racket, 29.5ms
# Speed: 2.2ms preprocess, 29.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 2 frisbees, 29.8ms
# Speed: 1.9ms preprocess, 29.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 2 handbags, 2 frisbees, 29.9ms
# Speed: 2.2ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 3 frisbees, 1 tennis racket, 29.8ms
# Speed: 2.2ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 5 handbags, 2 frisbees, 29.9ms
# Speed: 2.6ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 5 handbags, 2 frisbees, 30.6ms
# Speed: 2.5ms preprocess, 30.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 4 handbags, 2 frisbees, 29.3ms
# Speed: 2.8ms preprocess, 29.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 5 handbags, 2 frisbees, 29.8ms
# Speed: 2.4ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 4 handbags, 2 frisbees, 29.9ms
# Speed: 1.8ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 3 handbags, 2 frisbees, 30.1ms
# Speed: 2.6ms preprocess, 30.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 backpacks, 4 handbags, 2 frisbees, 29.8ms
# Speed: 1.9ms preprocess, 29.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 4 handbags, 2 frisbees, 30.2ms
# Speed: 2.0ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 3 handbags, 2 frisbees, 1 tennis racket, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 4 handbags, 2 frisbees, 1 tennis racket, 29.8ms
# Speed: 2.0ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 5 handbags, 3 frisbees, 29.8ms
# Speed: 2.1ms preprocess, 29.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 3 handbags, 2 frisbees, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 3 handbags, 2 frisbees, 29.6ms
# Speed: 4.0ms preprocess, 29.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 3 handbags, 2 frisbees, 29.9ms
# Speed: 2.8ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 3 handbags, 2 frisbees, 29.5ms
# Speed: 2.6ms preprocess, 29.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 3 handbags, 1 frisbee, 29.9ms
# Speed: 1.9ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 2 handbags, 1 frisbee, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 1 handbag, 1 frisbee, 30.2ms
# Speed: 2.2ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 3 handbags, 2 frisbees, 1 tennis racket, 29.4ms
# Speed: 2.0ms preprocess, 29.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 2 handbags, 2 frisbees, 30.3ms
# Speed: 2.0ms preprocess, 30.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 1 handbag, 2 frisbees, 30.2ms
# Speed: 1.9ms preprocess, 30.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 2 handbags, 2 frisbees, 37.1ms
# Speed: 2.5ms preprocess, 37.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 2 handbags, 2 frisbees, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 2 handbags, 2 frisbees, 1 tennis racket, 30.3ms
# Speed: 2.2ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 5 handbags, 1 frisbee, 30.2ms
# Speed: 2.0ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 4 handbags, 1 frisbee, 1 tennis racket, 30.3ms
# Speed: 1.9ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 6 handbags, 1 frisbee, 30.7ms
# Speed: 1.9ms preprocess, 30.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 5 handbags, 1 frisbee, 1 tennis racket, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 4 handbags, 1 frisbee, 1 tennis racket, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 1 frisbee, 1 tennis racket, 30.2ms
# Speed: 2.1ms preprocess, 30.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 3 handbags, 1 frisbee, 1 tennis racket, 30.3ms
# Speed: 1.9ms preprocess, 30.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 29.7ms
# Speed: 1.7ms preprocess, 29.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 3 handbags, 1 frisbee, 1 tennis racket, 30.9ms
# Speed: 3.0ms preprocess, 30.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 4 handbags, 1 frisbee, 1 tennis racket, 29.9ms
# Speed: 2.1ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 3 handbags, 1 frisbee, 1 tennis racket, 30.0ms
# Speed: 1.7ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 30.4ms
# Speed: 2.0ms preprocess, 30.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 1 tennis racket, 29.8ms
# Speed: 1.8ms preprocess, 29.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 29.7ms
# Speed: 3.4ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 2 frisbees, 29.9ms
# Speed: 1.9ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 frisbee, 29.5ms
# Speed: 4.3ms preprocess, 29.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 57.4ms
# Speed: 1.9ms preprocess, 57.4ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 2 frisbees, 1 tennis racket, 55.0ms
# Speed: 2.1ms preprocess, 55.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 1 handbag, 3 frisbees, 1 tennis racket, 53.0ms
# Speed: 6.4ms preprocess, 53.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 2 handbags, 1 frisbee, 28.4ms
# Speed: 2.4ms preprocess, 28.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 1 handbag, 1 frisbee, 30.0ms
# Speed: 7.7ms preprocess, 30.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 4 backpacks, 2 handbags, 1 frisbee, 48.4ms
# Speed: 2.4ms preprocess, 48.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 1 handbag, 1 frisbee, 46.6ms
# Speed: 3.0ms preprocess, 46.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 backpacks, 2 handbags, 1 frisbee, 32.8ms
# Speed: 4.1ms preprocess, 32.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 backpacks, 1 handbag, 1 frisbee, 29.5ms
# Speed: 2.5ms preprocess, 29.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 handbag, 1 frisbee, 41.3ms
# Speed: 2.7ms preprocess, 41.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 1 frisbee, 61.9ms
# Speed: 2.1ms preprocess, 61.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 1 handbag, 1 frisbee, 42.2ms
# Speed: 4.6ms preprocess, 42.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 backpacks, 1 frisbee, 38.4ms
# Speed: 5.3ms preprocess, 38.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 backpacks, 1 handbag, 1 frisbee, 40.8ms
# Speed: 11.5ms preprocess, 40.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 4 backpacks, 1 handbag, 1 frisbee, 50.7ms
# Speed: 3.5ms preprocess, 50.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 backpacks, 2 handbags, 1 frisbee, 39.8ms
# Speed: 7.6ms preprocess, 39.8ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 backpacks, 1 handbag, 1 frisbee, 44.6ms
# Speed: 14.4ms preprocess, 44.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 backpacks, 1 handbag, 1 frisbee, 59.0ms
# Speed: 2.4ms preprocess, 59.0ms inference, 41.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 backpacks, 1 handbag, 1 frisbee, 47.4ms
# Speed: 5.0ms preprocess, 47.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 backpacks, 1 handbag, 1 frisbee, 46.5ms
# Speed: 4.5ms preprocess, 46.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 backpacks, 1 handbag, 1 frisbee, 48.9ms
# Speed: 1.9ms preprocess, 48.9ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 1 handbag, 1 frisbee, 45.7ms
# Speed: 9.4ms preprocess, 45.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 2 handbags, 1 frisbee, 40.5ms
# Speed: 9.0ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 2 handbags, 1 frisbee, 52.9ms
# Speed: 2.2ms preprocess, 52.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 backpacks, 1 handbag, 1 frisbee, 41.8ms
# Speed: 2.1ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 39.8ms
# Speed: 2.0ms preprocess, 39.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 backpacks, 2 handbags, 1 frisbee, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 1 handbag, 2 frisbees, 66.2ms
# Speed: 5.2ms preprocess, 66.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 2 frisbees, 59.6ms
# Speed: 5.0ms preprocess, 59.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 2 frisbees, 46.9ms
# Speed: 2.2ms preprocess, 46.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 44.9ms
# Speed: 2.1ms preprocess, 44.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 2 handbags, 39.8ms
# Speed: 4.4ms preprocess, 39.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 1 handbag, 1 frisbee, 38.3ms
# Speed: 2.8ms preprocess, 38.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 2 handbags, 1 frisbee, 37.6ms
# Speed: 4.0ms preprocess, 37.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 backpacks, 2 handbags, 1 frisbee, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 backpacks, 1 handbag, 1 frisbee, 31.1ms
# Speed: 4.6ms preprocess, 31.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 backpacks, 1 handbag, 1 frisbee, 36.1ms
# Speed: 2.5ms preprocess, 36.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 1 suitcase, 1 frisbee, 31.7ms
# Speed: 6.9ms preprocess, 31.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 1 handbag, 1 frisbee, 45.9ms
# Speed: 2.0ms preprocess, 45.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 handbag, 1 frisbee, 30.9ms
# Speed: 3.6ms preprocess, 30.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 handbag, 1 frisbee, 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 handbag, 1 frisbee, 41.3ms
# Speed: 4.2ms preprocess, 41.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 1 handbag, 1 frisbee, 59.1ms
# Speed: 2.3ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 backpacks, 1 handbag, 1 frisbee, 31.2ms
# Speed: 10.1ms preprocess, 31.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 1 frisbee, 31.7ms
# Speed: 8.2ms preprocess, 31.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
